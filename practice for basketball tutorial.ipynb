# %%
import numpy as np
year=["2018","2019","2020","2021","2022"]
ydict={"2018":0,"2019":1,"2020":2,"2021":3,"2022":4}
ansh=[1234,2341,2537,9372,2635]
saurabh=[1000,20000,3500,4000,5000]
Salary=np.array([ansh,saurabh])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(0,2):
    plt.plot(Salary[i],c="blue",ls="--",marker="d",ms=5)
plt.xticks(list(range(0,len(year))),year,rotation="vertical")
plt.show()

# %%
ydict["2020"]
# Out:
# 2

# %%
Salary
# Out:
# array([[ 1234,  2341,  2537,  9372,  2635],
#        [ 1000, 20000,  3500,  4000,  5000]])

# %%
Salary[:,2]
# Out:
# array([2537, 3500])
