# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kumar\\Desktop\\Python Course\\udemy-Data Science'

# %%
movie=pd.read_csv('MovieRatings.csv')
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movie.describe().transpose()
# Out:
#                            count         mean        std     min     25%  \
# Rotten Tomatoes Ratings %  559.0    47.309481  26.413091     0.0    25.0
# Audience Ratings %         559.0    58.744186  16.826887     0.0    47.0
# Budget (million $)         559.0    50.236136  48.731817     0.0    20.0
# Year of release            559.0  2009.152057   1.362632  2007.0  2008.0
#
#                               50%     75%     max
# Rotten Tomatoes Ratings %    46.0    70.0    97.0
# Audience Ratings %           58.0    72.0    96.0
# Budget (million $)           35.0    65.0   300.0
# Year of release            2009.0  2010.0  2011.0

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns=['Film','Genre','CriticRating','AudienceRatings','BudgetMillion','Year']
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
# category data type
movie.Film =movie.Film.astype('category')
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movie.Genre =movie.Genre.astype('category')
movie.BudgetMillion =movie.BudgetMillion.astype('long')
movie.Year =movie.Year.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int32
#  5   Year             559 non-null    category
# dtypes: category(3), int32(1), int64(2)
# memory usage: 38.2 KB

# %%
print(movie.Genre.unique()) 
print()
print(movie.Genre.cat.categories)
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
#
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int32
#  5   Year             559 non-null    category
# dtypes: category(3), int32(1), int64(2)
# memory usage: 38.2 KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion
# count    559.000000       559.000000     559.000000
# mean      47.309481        58.744186      50.236136
# std       26.413091        16.826887      48.731817
# min        0.000000         0.000000       0.000000
# 25%       25.000000        47.000000      20.000000
# 50%       46.000000        58.000000      35.000000
# 75%       70.000000        72.000000      65.000000
# max       97.000000        96.000000     300.000000

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %%
# working with jointplots

# %%
plot1=sb.jointplot(data=movie,x='CriticRating',y='AudienceRatings')

# %%
plot2=sb.jointplot(data=movie,x='CriticRating',y='AudienceRatings',kind='hex')

# %% [markdown]
# ---

# %%
#histogram

# %%
plot3=sb.displot(movie["AudienceRatings"], bins=15)

# %%
sb.set_style("dark")
plot4=plt.hist(movie.CriticRating, bins=15,density=False,stacked=True)

# %%
#stacked Histograms
---
# Out:
#   File "<ipython-input-22-c9d3069a49c9>", line 2
#     ---
#        ^
# SyntaxError: invalid syntax

# %%
sb.set_style("darkgrid")
plot5=plt.hist(movie[movie.Genre=="Action"].BudgetMillion)

# %%
plot6_1=plt.hist(movie[movie.Genre=="Action"].BudgetMillion,bins=15)
plot6_2=plt.hist(movie[movie.Genre=="Drama"].BudgetMillion,bins=15)
plot6_3=plt.hist(movie[movie.Genre=="Thriller"].BudgetMillion,bins=15)
#here the barsgraphs are hidding behind each other,what we want is to show evry detail\
#for that we have to contain all the data in a single list and print that list as a plot

# %%
plot7=plt.hist([movie[movie.Genre=="Action"].BudgetMillion,\
    movie[movie.Genre=="Drama"].BudgetMillion,\
    movie[movie.Genre=="Thriller"].BudgetMillion],\
        bins=15,stacked=True)

# %%
list1=[]
mylabels=[]
for i in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre==i].BudgetMillion)
    mylabels.append(i)
    
plot8=plt.hist(list1,bins=25,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# #KDE=Kernel Density Estimate plot

# %%
plot9=sb.lmplot(data=movie,x="CriticRating",y="AudienceRatings",fit_reg=False,hue="Genre",size=7,aspect=2)

# %%
#KDE=Kernel Density Estimate plot of the above plot is:

plot10=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,shade=True,shade_lowest=False,cmap="Reds")

# %%
plot10=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,shade=True,shade_lowest=False,cmap="Reds")
#Tip
plot10b=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,cmap="Reds")

# %% [markdown]
# # subplots

# %%
f, axes=plt.subplots(1,2, figsize=(15,6),sharex=True,sharey=True)
sb.set_style("dark")
plot11=sb.kdeplot(movie.BudgetMillion,movie.AudienceRatings, ax=axes[0])
plot12=sb.kdeplot(movie.BudgetMillion,movie.CriticRating, axes=[1])

# %%
#for 2-d subplotting
f, axes=plt.subplots(2,2 , figsize=(12,6), sharex=True,sharey=True) # sharex and sharey is for shareing the x and y axis with the whole graph
plot11b=sb.kdeplot(movie.BudgetMillion,movie.AudienceRatings, ax=axes[0,0])
plot12b=sb.kdeplot(movie.BudgetMillion,movie.CriticRating, ax=axes[0,1])
plot11b=sb.kdeplot(movie.BudgetMillion,movie.AudienceRatings, ax=axes[1,0])
plot12b=sb.kdeplot(movie.BudgetMillion,movie.CriticRating, ax=axes[1,1])
plot11b.set(xlim=(-50,300)) #for setting the axis
# Out:
# [(-50.0, 300.0)]

# %% [markdown]
# # ViolenPlots

# %%
plot13=sb.violinplot(data=movie[movie.Genre=="Drama"], x="Year" ,y="CriticRating")

# %%
plot14=sb.boxplot(data=movie[movie.Genre=="Drama"], x="Year" ,y="CriticRating")

# %% [markdown]
# # Facet_Grid

# %%
plot15=sb.FacetGrid(movie, row='Genre',col='Year',hue='Genre')

# %%
plot15=sb.FacetGrid(movie, row='Genre',col='Year',hue='Genre')
plot16=plot15.map(plt.scatter,'CriticRating','AudienceRatings')

# %%
    #can populate with any kind of chart like hist,scatter,etc.
    #Example
    plot17=sb.FacetGrid(movie, row='Genre',col='Year',hue='Genre')
    plot17b=plot17.map(plt.hist,'AudienceRatings')

# %%
#back to the scatter plot
plot18=sb.FacetGrid(movie, row='Genre',col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5, edgecolor='black')
plot18=plot18.map(plt.scatter,'CriticRating','AudienceRatings',**kws)
plot18.set(xlim=(0,100),ylim=(0,100))
# here we are generating the keyword(i.e kws) which contains the different datas like size edge color ect.
#then passing it in the map parameter


for ax in plot18.axes.flat:
    ax.plot((0,100), (0,100), c='black', ls='--')
plot18.add_legend()

# %% [markdown]
# # Building Dashboard

# %%
sb.set_style("darkgrid")
f, axes=plt.subplots(2, 2, figsize=(20,15)) 
plot19a=sb.kdeplot(movie.BudgetMillion,movie.AudienceRatings, ax=axes[0,0]) 
plot19b=sb.kdeplot(movie.BudgetMillion,movie.CriticRating, ax=axes[0,1]) 
plot19c=sb.violinplot(movie.Year,movie.CriticRating, ax=axes[1,0])
#plot19d=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,shade=True,shade_lowest=False,cmap="Reds",
       # ax=axes[1,1])
#Tip
#plot19_1d=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,cmap="Reds", ax=axes[1,1])

#if we want to add a pyplot plot in dashboard then for that we have a different approach.Ex-
axes[1,1].hist([movie[movie.Genre=="Action"].BudgetMillion,\
    movie[movie.Genre=="Drama"].BudgetMillion,\
    movie[movie.Genre=="Thriller"].BudgetMillion],\
        bins=15,stacked=True )
plt.show()

# %% [markdown]
# # Styling Dashboard tips

# %%
sb.set_style("dark",{"axes.facecolor": "black"})
f, axes=plt.subplots(2, 2, figsize=(20,15)) 
#plot[0,0]
plot19a=sb.kdeplot(movie.BudgetMillion,movie.AudienceRatings ,cmap='inferno',shade_lowest=True,shade=True, ax=axes[0,0]) 
plot19a=sb.kdeplot(movie.BudgetMillion,movie.AudienceRatings ,cmap='gnuplot',shade_lowest=True,shade=True, ax=axes[0,0]) 

#plot[0,1]
plot19b=sb.kdeplot(movie.BudgetMillion,movie.CriticRating,cmap='gnuplot2',shade=True,shade_lowest=True, ax=axes[0,1]) 

#plot[1,0]
plot19c=sb.violinplot(movie.Year,movie.BudgetMillion, ax=axes[1,0], palette='cool')

#plot[1,1]
plot19d=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,shade=True,shade_lowest=False,cmap="Blues",
       ax=axes[1,1])
plot19_1d=sb.kdeplot(data=movie,x="CriticRating",y="AudienceRatings",size=10,aspect=2,cmap="jet_r", ax=axes[1,1])

#if we want to add a pyplot plot in dashboard then for that we have a different approach.Ex-
#axes[1,1].hist([movie[movie.Genre=="Action"].BudgetMillion,\
 #   movie[movie.Genre=="Drama"].BudgetMillion,\
  #  movie[movie.Genre=="Thriller"].BudgetMillion],\
   #     bins=15,stacked=True )
plt.show()

# %% [markdown]
# # Thematic edits

# %%
sb.set_style("whitegrid")
fig,ax=plt.subplots()
plt.title('Chart of Genre vs BudgetMillion', fontsize=30,color='Blue')
plt.ylabel("Number of Movies", fontsize =25, color="Black")
plt.xlabel('BudgetMillion', fontsize=20, color="Black")
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
fig.set_size_inches(11.4,8.27)
list1=[]
mylabels=[]
for i in movie.Genre.cat.categories:
    list1.append(movie[movie.Genre==i].BudgetMillion)
    mylabels.append(i)
    
plot8=plt.hist(list1,bins=25,stacked=True,rwidth=1,label=mylabels)
plt.legend(frameon=True,fancybox=True,shadow=True ,framealpha=1,prop={'size':20})
plt.show()
